# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/sg_90k_part1.json'

# %%
import json

with open(file_path) as f:
  data = json.load(f)
  length = len(data)
  print(length)
# Out:
# 45332

# %%
# !pip install markdownify
# Out:
# Collecting markdownify
#   Downloading markdownify-0.11.6-py3-none-any.whl (16 kB)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /usr/local/lib/python3.10/dist-packages (from markdownify) (4.12.3)
# Requirement already satisfied: six<2,>=1.15 in /usr/local/lib/python3.10/dist-packages (from markdownify) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5,>=4.9->markdownify) (2.5)
# Installing collected packages: markdownify
# Successfully installed markdownify-0.11.6

# %%
"""
- Convert html to markdown with basic data cleaning.
- Deduplication.

Usage:
python3 -m fastchat.data.clean_sharegpt --in sharegpt_html.json --out sharegpt_clean.json
"""
import argparse
from concurrent.futures import ProcessPoolExecutor
import json
import logging
import re
from typing import Dict, Union

import bs4
import markdownify  # == 0.11.6
from tqdm import tqdm


div_pattern = re.compile("<div.*?>")
span_pattern = re.compile("<span.*?>")
code_lang_pattern = re.compile(
    "```\s*" + "(.*?)" + "(?:Copy code)+" + "(.+?)" + "\s*?```", re.DOTALL
)
code_lang_format = "```\g<1>\n\g<2>\n```"
regenerate_pattern = re.compile("\d+ / \d+")
copy_chars_pattern = re.compile("Copy\d+ chars / \d+ words")
copy_code_pattern = re.compile("```(.*?)Copy code\s*```")


def reformat_code(val: str) -> str:
    # Input code format is:
    # ```
    # $<language>Copy code$<exact_code_here>
    #
    # ```
    # This function convert it into the correct markdown format
    return re.sub(code_lang_pattern, code_lang_format, val)


def html_to_markdown(val: str) -> str:
    # Remove all <div>. This is required to make intent work in code blocks.
    val = re.sub(div_pattern, "", val)
    # Remove all <span>. This is required to make underscores work in code blocks.
    val = re.sub(span_pattern, "", val)
    # Markdown to html
    val = markdownify.markdownify(val).strip()
    # Reformat code
    val = reformat_code(val)

    # Remove noisy "[number] / [number]" at the beginning
    noise = re.search(regenerate_pattern, val)
    if noise and noise.start() == 0:
        val = val[noise.end() :]
    # Remove noisy "Copy[number] chars / [number] words"
    val = re.sub(copy_chars_pattern, "", val)
    # Remove empty code block ```\nCopy code\n```
    val = re.sub(copy_code_pattern, "", val)

    # Strip
    val = val.replace("\n\n\n", "\n").strip()

    return val


def contain_blocked_words(val: str) -> bool:
    blocked_words = ["openai", "chatgpt"]
    for w in blocked_words:
        if w in val.lower():
            return True
    return False


def clean_html_one_sample(sample):
    roles = ["human", "gpt"]

    if len(sample["conversations"]) <= 1:
        return (sample, 1)

    # Adjust the offset for cases like https://sharegpt.com/c/VyaZlh4
    if sample["conversations"][0]["from"] != "human":
        sample["conversations"] = sample["conversations"][1:]
    if len(sample["conversations"]) <= 1:
        return (sample, 1)

    if sample["conversations"][-1]["from"] == "human":
        sample["conversations"] = sample["conversations"][:-1]
    if len(sample["conversations"]) <= 1:
        return (sample, 1)

    char_count = 0
    new_conversations = []
    for i, c in enumerate(sample["conversations"]):
        if c["from"] != roles[i % 2]:
            return (sample, 2)

        if contain_blocked_words(c["value"]):
            return (sample, 3)

        try:
            new_val = html_to_markdown(c["value"])
        except (bs4.builder.ParserRejectedMarkup, AssertionError):
            return (sample, 4)

        # Filter empty answers like https://sharegpt.com/c/mrllZ6u
        if not new_val or not new_val[0].isprintable():
            break

        char_count += len(new_val)
        new_conversations.append(
            {
                "from": c["from"],
                "value": new_val,
            }
        )

    new_conversations = new_conversations[: len(new_conversations) // 2 * 2]
    sample["conversations"] = new_conversations

    if char_count < 16 or len(sample["conversations"]) <= 0:
        return (sample, 1)

    return (sample, 0)


def clean_html_all(content, begin, end):
    """
    Clean the source html files.
    """
    cnt_skip = 0
    cnt_blocked_words = 0
    cnt_wrong_format = 0
    cnt_parser_error = 0
    cnt_too_short = 0
    cnt_id_duplication = 0
    cnt_value_duplication = 0
    cnt_plugin = 0
    cnt_tag = 0

    content = content[begin:end]
    processed = []
    with ProcessPoolExecutor() as executor:
        for result in tqdm(
            executor.map(clean_html_one_sample, content), total=len(content)
        ):
            processed.append(result)

    visited = {}
    new_content = []
    for sample, error_code in processed:
        cid = sample["id"]
        skipped = True

        if error_code != 0:
            if error_code == 1:
                print(f"id {cid} is too short")
                cnt_too_short += 1
            elif error_code == 2:
                print(f"id {cid} has a wrong format")
                cnt_wrong_format += 1
            elif error_code == 3:
                print(f"id {cid} contains blocked words")
                cnt_blocked_words += 1
            elif error_code == 4:
                print(f"id {cid} contains parser errors")
                cnt_parser_error += 1
            else:
                raise ValueError(f"Invalid error_code: {error_code}")
        elif cid in visited:
            print(f"id {cid} is an id duplication of {visited[cid]}")
            cnt_id_duplication += 1
        elif sample.get("plugins", None) is not None:
            print(f"id {cid} contains plugin")
            cnt_plugin += 1
        else:
            key = (
                sample["conversations"][0]["value"],
                sample["conversations"][1]["value"],
            )
            if key in visited:
                print(f"id {cid} is a value duplication of {visited[key]}")
                cnt_value_duplication += 1
            else:
                visited[cid] = visited[key] = cid
                skipped = False

        if not skipped:
            new_content.append(sample)
        else:
            cnt_skip += 1

    print(
        f"total: {len(content)}, skip: {cnt_skip}, new: {len(new_content)}, "
        f"cnt_blocked_words: {cnt_blocked_words}, cnt_parser_error: {cnt_parser_error}, "
        f"cnt_wrong_format: {cnt_wrong_format}, "
        f"cnt_too_short: {cnt_too_short}, cnt_id_duplication: {cnt_id_duplication}, "
        f"cnt_value_duplication: {cnt_value_duplication}, cnt_plugin: {cnt_plugin}"
    )

    return new_content


def main():
    in_file = '/content/drive/My Drive/sg_90k_part1.json'
    out_file = 'sharegpt_clean.json'
    begin = 1
    end = 45332  # Process only first 5 rows

    content = json.load(open(in_file, "r"))
    content = clean_html_all(content, begin, end)
    json.dump(content, open(out_file, "w"), indent=2, ensure_ascii=False)

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/markdownify/__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
# /usr/local/lib/python3.10/dist-packages/markdownify/__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
# /usr/local/lib/python3.10/dist-packages/markdownify/__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
# /usr/local/lib/python3.10/dist-packages/markdownify/__init__.py:96: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   soup = BeautifulSoup(html, 'html.parser')
#  12%|█▏        | 5369/45331 [00:43<04:08, 160.51it/s]/usr/lib/python3.10/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
#  33%|███▎      | 15058/45331 [02:02<03:36, 140.13it/s]/usr/lib/python3.10/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)
# 100%|██████████| 45331/45331 [06:03<00:00, 124.65it/s]
# Streaming output truncated to the last 5000 lines.
# id 6Fg09Ek contains blocked words
# id XBWxQmO contains blocked words
# id LazxCQY is too short
# id lpdMwau has a wrong format
# id Pa5zD8I is a value duplication of MwBHYue
# id 539R1Pm is a value duplication of 598BaQ3
# id xnYsKYh is a value duplication of hvEAUtZ
# id 46Kmrcr contains blocked words
# id 1X9zoXb contains blocked words
# id mrWaS1S is a value duplication of 7XcoZjQ
# id 8vObiZi contains blocked words
# id cdHv2yl is a value duplication of yp0SLIe
# id hLCh4iD is a value duplication of z7hfXP3
# id OunYal2 is a value duplication of bL4XwMu
# id voDhDIL has a wrong format
# id AhfoiqU contains blocked words
# id zc6CuYD is a value duplication of UW3sR2H
# id dql02O1 is a value duplication of Hl3Mjtv
# id d7BZs2r contains blocked words
# id DXj8HYg contains blocked words
# id mA8oZ02 contains blocked words
# id lrMKHA1 contains blocked words
# id 6cDSYSg is a value duplication of J8OZv8f
# id qivgZxA is a value duplication of BjaXxo3
# id s71n9Yl is a value duplication of RO65TuS
# id BJRfOuT contains blocked words
# id sdQ97pQ is a value duplication of eEg0anT
# id IoTZgly is a value duplication of ftoCcOn
# id mmWGYki is a value duplication of GzdtWkn
# id 1GdL5nD contains blocked words
# id FDJIznU is a value duplication of c9kDAOA
# id s2J5GA7 is too short
# id UAkPyXY contains blocked words
# id cx9no1o contains blocked words
# id czfaN2Y has a wrong format
# id Mcmc6w5 contains blocked words
# id hX24B9m is too short
# id 0eQU3PJ contains blocked words
# id yZzMJcG contains blocked words
# id 3dXYzva is too short
# id R8kEdn5 contains blocked words
# id dMRuG3S is too short
# id rzhbhtd contains blocked words
# id o4xKrbg is a value duplication of RyPI6hJ
# id fQmTS1I is a value duplication of z46tGl7
# id n42dRB1 is a value duplication of 99PgYyD
# id gsAXzGr contains blocked words
# id C0TZw0d has a wrong format
# id L9OnYPE is too short
# id tK0n9ud has a wrong format
# id GAoHwbB is a value duplication of GUgn72u
# id BKKb6OG contains blocked words
# id iaIJHe3 has a wrong format
# id ht2LC60 contains blocked words
# id D6TTJ3C is a value duplication of WZMcE8f
# id tQYj2B0 is a value duplication of 4attZep
# id VgMDInj contains blocked words
# id htSCqmh is a value duplication of efcAzKB
# id addXUW9 is too short
# id IZx8cse has a wrong format
# id lJX6p95 contains blocked words
# id 3pCPMEZ contains blocked words
# id e5FYp4j contains blocked words
# id DqIBVCx is a value duplication of sKSAz3S
# id GBWBjBo is a value duplication of hliJQ1G
# id YFhooem contains blocked words
# id 53nVzIB contains blocked words
# id cJJ8xid is too short
# id Pznhjax is too short
# id Np3HIdA is a value duplication of dfJACtG
# id JbIUnNa contains blocked words
# id bwJgk19 is a value duplication of fyT6BUy
# id EnsCk4l contains blocked words
# id RJsqSvh contains blocked words
# id 7BONfe5 is a value duplication of sIMwLZY
# id J7SK1D1 is a value duplication of SCk4ZLX
# id cz6dA15 is a value duplication of lPT8aIE
# id ywXN050 is a value duplication of WU9vDxk
# id 7HO6cKd contains blocked words
# id xVoEHce contains blocked words
# id mFOMXsJ has a wrong format
# id BQt7GL9 contains blocked words
# id PQ0Us8Q is a value duplication of SCk4ZLX
# id PMqlfuo contains blocked words
# id i8xL0ih is a value duplication of 5PrPANu
# id ZU5WSDe is too short
# id 8rbvMQI contains blocked words
# id RX0dufP is a value duplication of JYZ77A7
# id sc2uqsm is a value duplication of nwki9m9
# id Uzf1e6n contains blocked words
# id cMnnNgj is a value duplication of tN8D9M3
# id RhHukiu contains blocked words
# id 84G6xc7 is a value duplication of DKSTfSq
# id bHG4sRc is too short
# id UV1jhcU has a wrong format
# id c56Wx3B contains blocked words
# id 0kcdnbX is a value duplication of YblmreD
# id mDmGmWH contains blocked words
# id K9wgise contains blocked words
# id d1kfQzm contains blocked words
# id UAqA6bq contains blocked words
# id tDAWGcD contains blocked words
# id UZefQkz is a value duplication of 0yEFKLt
# id MnqZFr8 is a value duplication of Ro6kA2M
# id yOXlyQE contains blocked words
# id lq6JAtK contains blocked words
# id Evso1Iq contains blocked words
# id Onuprpa is a value duplication of yXgLvCA
# id Ezo75TM is a value duplication of lXnBLZD
# id WOVx9hV contains blocked words
# id iHD1ZdM contains blocked words
# id R4NkF6H contains blocked words
# id Sr5nZqP contains blocked words
# id uhpyiWd is too short
# id 2MkbTrv is too short
# id pfU7WFf contains blocked words
# id d1pBgDs is a value duplication of etYYkyZ
# id uMK9Deg is a value duplication of 65aJHi3
# id i5lSXXl contains blocked words
# id SDFNmP8 is a value duplication of XfzAoCy
# id E32hmbN is a value duplication of d0cMOju
# id JSgQnV9 is a value duplication of O3FeoHQ
# id vH636g3 is too short
# id w9gseRK contains blocked words
# id 8RZNBb1 contains blocked words
# id LWMydUQ contains blocked words
# id nyJHiMk is a value duplication of eYbUB9g
# id hkfF6Yu contains blocked words
# id C8VdwEG contains blocked words
# id 5J2sNZe is a value duplication of XRTH3YB
# id IDmx2Kp contains blocked words
# id UTFnspq is a value duplication of Vzwlwmt
# id Fh6z0xV contains blocked words
# id zjIEcnj is a value duplication of f6YTM5s
# id k8XoT1N contains blocked words
# id kr6KBdN contains blocked words
# id 8MegsDw is a value duplication of feGYmhU
# id HHGCst6 is a value duplication of ORu8lOj
# id 6dRQDTG contains blocked words
# id 1nzwM74 is a value duplication of 0ufRuJd
# id THRFBj6 is a value duplication of Fi8FsPY
# id Ch594Jx contains blocked words
# id f1YgzXW is a value duplication of D5Ahfot
# id 2bkfY2U contains blocked words
# id Eem8RLQ is a value duplication of PypzwLG
# id dgiVUxr has a wrong format
# id ATmylIf contains blocked words
# id bp8j9ae is a value duplication of Efo6agT
# id 0OOcdq8 is a value duplication of nS5LZUy
# id 2Gjzn2S is too short
# id FPBh7Y4 is a value duplication of 0RDEfFm
# id vEzcs9M contains blocked words
# id CfAEtS1 is a value duplication of zaHpZ1e
# id 8zRKMI9 is a value duplication of uhjuTFC
# id c5ACUdY is too short
# id HV9uQWm is a value duplication of VmLZ5PG
# id 1XMcztS has a wrong format
# id p1Q9e8a is a value duplication of lP6kixz
# id 4pkL5Gr is too short
# id pU9ofkS contains blocked words
# id YhD7wkS contains blocked words
# id WjdUClw is a value duplication of 3SHRK8r
# id iRj9WhA contains blocked words
# id LZZA746 has a wrong format
# id 8KUUjiI contains blocked words
# id 8Vv1GmR is a value duplication of lFfOTSf
# id lRx4mCM is a value duplication of SSKuuA6
# id dfEXgNx contains blocked words
# id x6EBHQ7 is a value duplication of iYnvCyM
# id T346190 contains blocked words
# id iZ3hxJa contains blocked words
# id BMMigfg is a value duplication of fcBjchm
# id 9sJW8sy is a value duplication of KFSLwD6
# id ROej7Sm contains blocked words
# id tIR2uPS is too short
# id eD4uuqr contains blocked words
# id G4XUPl8 is too short
# id 7l2InqC contains blocked words
# id YNmMayt is too short
# id JzpPjZJ is a value duplication of BwNBGbr
# id VuuvJdh contains blocked words
# id L0F1yy3 is a value duplication of zpaj9oH
# id BEbe20V is a value duplication of rV8aVGd
# id Z55yT8U is a value duplication of TeDHocG
# id uIWT55G contains blocked words
# id G3XZba5 contains blocked words
# id 8Ei88kb is a value duplication of xasomVD
# id qKnJ6Sz has a wrong format
# id kyWEvDJ has a wrong format
# id naE73n6 is a value duplication of hntvkG9
# id ThTzAFU contains blocked words
# id 3dLiuPK is too short
# id UoUgHBm contains blocked words
# id ZsItvnJ has a wrong format
# id yIZxPoQ is a value duplication of PjXXCHp
# id 4XrdWZi is too short
# id X6m6gN4 is a value duplication of YWIiBrA
# id cGVwbCi is a value duplication of iI2dK8N
# id 56f62PS is a value duplication of b6XFATU
# id ddATTgB is a value duplication of 5nINNyc
# id yXAlFu3 is a value duplication of bvlM9fm
# id eQQaCGa contains blocked words
# id fKbxg6G contains blocked words
# id Gv32kwT is a value duplication of V2Ke5sc
# id u6Y1h9m contains blocked words
# id RFaPMZL contains blocked words
# id CxXn9tv contains blocked words
# id WByzvza is too short
# id o7FD37T is a value duplication of OOPHWyr
# id Dc0KBUq contains blocked words
# id VjKKBNF is a value duplication of m2T9X3o
# id F77Jkg7 contains blocked words
# id s1ESaQ3 contains blocked words
# id SEs0SaQ has a wrong format
# id h2Wk4Ik is a value duplication of 15Ef23p
# id fneUrb6 is too short
# id Q80Yhcs contains blocked words
# id OZ34W3h is a value duplication of HebkhJf
# id 4xvrGwV is too short
# id L6dsGdC is a value duplication of sg43Pml
# id 6RhWh90 is too short
# id pUIPSGP is a value duplication of ifOkUoO
# id 4Mg4ux2 is a value duplication of bnYaogc
# id xQeX3tc contains blocked words
# id GdA7gkI contains blocked words
# id AFqa9uB is a value duplication of SOIrAce
# id fpagqtf contains blocked words
# id YkAbU7B is a value duplication of fZ7SRXq
# id 3tkfeeb is too short
# id M71GEnw has a wrong format
# id ut4MUzM is too short
# id ruVJaUe contains blocked words
# id VhFIexE contains blocked words
# id n87L2dq is a value duplication of qRnLLZD
# id BG0bP7H is a value duplication of 2VlPlPE
# id VnxdbXP is a value duplication of KUUoD2R
# id ksLKvfJ contains blocked words
# id 1ZDrv9M contains blocked words
# id mqyLCz1 contains blocked words
# id fEPiLG7 is a value duplication of LtC9nfI
# id 1jgnLoB is a value duplication of hG4OMpU
# id 8e4rjAl has a wrong format
# id aX0EBqW is too short
# id prcQFqN is a value duplication of xFOGGTt
# id 7ybXDjI is a value duplication of at1lSJX
# id oeW6OUk is a value duplication of brc2wJS
# id GABcyha contains blocked words
# id lozTyij is a value duplication of FpzUV2p
# id 0ty2GN7 is a value duplication of nYW85MP
# id Dcwfr5F is a value duplication of yrSSuFo
# id gvxP9i4 contains blocked words
# id Gay8UDf is a value duplication of 8eBYncZ
# id nI0fFTR contains blocked words
# id YthsiL3 contains blocked words
# id ozG9QQx is a value duplication of xFOGGTt
# id 4ryDHyS is a value duplication of 1bziJ0t
# id cYrCVVh is a value duplication of TC3eR9p
# id ZfJFtmY has a wrong format
# id NV6KCSm has a wrong format
# id LwulkJS is a value duplication of HRTW8KY
# id unwdGag is a value duplication of 9qx6mw3
# id eid69De is too short
# id DDMH7n5 has a wrong format
# id Etx35N8 has a wrong format
# id XXiC90o contains blocked words
# id l6BPwJj is too short
# id pbMY1A2 is a value duplication of TsHZJpJ
# id 5kZhNye is a value duplication of AgvQC7y
# id 1QlLMvz is a value duplication of gzINxlO
# id 5D2ZF8X contains blocked words
# id cUIIsE1 contains blocked words
# id aMhivMX is a value duplication of eql5tQa
# id FACRcav has a wrong format
# id bJr6m6r has a wrong format
# id 4nwgpm9 is a value duplication of d5RjPao
# id kWPAysr contains blocked words
# id ynkEhtm is too short
# id bKFtKkn contains blocked words
# id uIaQBjo contains blocked words
# id c5T5rTn is a value duplication of 2VlPlPE
# id iFMK3jj is a value duplication of DMd882k
# id ocYkhG7 contains blocked words
# id CdXAqMw contains blocked words
# id WBU0bcz is too short
# id 1aFCiq2 has a wrong format
# id gj3XyZW is a value duplication of aKWGRy6
# id 1j2xxfu has a wrong format
# id 0c6v0cu is too short
# id YFmUi3Q contains blocked words
# id jvtRJ4k contains blocked words
# id ohQDRgu contains blocked words
# id mYAHwxt has a wrong format
# id jROnbjY is a value duplication of uKwaWn8
# id t0sFSOl is a value duplication of 70NCK0N
# id mfVuRD0 is too short
# id pQyYfzF contains blocked words
# id SZS77xJ is too short
# id 0IJSX5q contains blocked words
# id sm0qkXx contains blocked words
# id b4PuPgz is too short
# id IhPmwOc has a wrong format
# id KqsVjdP is a value duplication of Wgg38PC
# id 0kcsoXh has a wrong format
# id h0ATlci contains blocked words
# id 7I5m0O9 contains blocked words
# id vbE2KVw is a value duplication of tlmJDXw
# id R6aFcpC is a value duplication of vKtnoJG
# id OO4NqH9 contains blocked words
# id VE3ymcm is a value duplication of rWsWC0w
# id BmRxBS3 contains blocked words
# id mye1GS7 is a value duplication of WhbIwSf
# id F0dPlXf is a value duplication of HetaDay
# id Sq035dR is too short
# id coE7NaO contains blocked words
# id aN6Dq4B is a value duplication of gnNJNXp
# id a4iwqOR has a wrong format
# id MihMPxj is a value duplication of egSNp86
# id 7Jp714y is too short
# id 8QfmspA contains blocked words
# id kdiAj3z is a value duplication of GpQsWxh
# id vp8nvvL contains blocked words
# id yi23jgg is a value duplication of JjherX8
# id U6DB6if is a value duplication of qs2ujH0
# id A96mbIA is a value duplication of 4XkFF3P
# id UqgidNX contains blocked words
# id LJHEI5U is too short
# id PMQmeWK is a value duplication of eATZViH
# id ojxcbty contains blocked words
# id CJs2qC2 is a value duplication of GGDMJ7s
# id QHAEiih is a value duplication of gSp8J0w
# id hf0jNgr is too short
# id 96UYUBc has a wrong format
# id 7AJRGfY contains blocked words
# id ijpoTmP is a value duplication of VdA4ReI
# id 2BFbS0C is too short
# id h0Uog2t contains blocked words
# id NAiQ3D5 contains blocked words
# id 8yJxClP contains blocked words
# id t9RupyU is a value duplication of egE4suh
# id taUx1Rj is a value duplication of 0xZAev2
# id uJTmdB3 is a value duplication of L6FiY92
# id BMls9F9 contains blocked words
# id IhThith is too short
# id Q5pEZLD contains blocked words
# id EBDryPS is a value duplication of QvhCGvp
# id VpwmKqM is a value duplication of d5RjPao
# id KNzuRIH is too short
# id WwGaSii is a value duplication of J6hOJZz
# id qFg1yYy is a value duplication of 5eEBwFI
# id lH1hKUM is a value duplication of KwF5fWE
# id Zgz5xLP contains blocked words
# id CADzwUt contains blocked words
# id 7ZDB9AD contains blocked words
# id ZX4hNxr contains blocked words
# id 37fNKx8 is too short
# id hNVr98O has a wrong format
# id iuTjOFn is a value duplication of hJzG6Lf
# id EWjbUAI is too short
# id sUPll6X has a wrong format
# id 98knIXJ is too short
# id mtS31VO is a value duplication of 7T5cv1p
# id SRxUWCk is a value duplication of rYlUyr1
# id VLdAQSL contains blocked words
# id rpkKzBE is a value duplication of SCk4ZLX
# id bFA46pZ contains blocked words
# id 3W1P4jd contains blocked words
# id YIgzO1o is a value duplication of wHwsw8s
# id sd6dEBQ contains blocked words
# id uN0REvi is a value duplication of ao5zYKj
# id gIiG5EC contains blocked words
# id EbLElsj contains blocked words
# id 838EFJv contains blocked words
# id nChtZbt has a wrong format
# id 11RzLkH is a value duplication of HoulfYD
# id DnBUoLy is a value duplication of v4PzAY8
# id fLPRxq3 contains blocked words
# id 94FVQ5X has a wrong format
# id YeJFO6E contains blocked words
# id CYXZRzo is a value duplication of ybmtwv1
# id sQ50QQx is a value duplication of fbheJeB
# id hEl9mc9 contains blocked words
# id aSRdjll contains blocked words
# id MCBlTlW contains blocked words
# id NS0bQHz is a value duplication of 80HCUMd
# id mTlmZJE contains blocked words
# id 9MCZxAh is a value duplication of 5dTR6cA
# id OkR4WvF is a value duplication of AcGGE1g
# id Fg6q54X is too short
# id ruEBgwH is too short
# id wQSrtGA contains blocked words
# id mZRGBwM is too short
# id aDFbK33 is a value duplication of 7FEtxbH
# id H6E2LeT is a value duplication of 9xHTDAm
# id FLkZanz contains blocked words
# id dA50t6V contains blocked words
# id vWKZpwM is a value duplication of 6dPUCcK
# id fN6CiHG contains blocked words
# id mBVPR9a has a wrong format
# id jRI5Sv3 contains blocked words
# id Y6Tq5qf is a value duplication of kgU7ApZ
# id r4oQFzc is a value duplication of Ei7E40n
# id oXXZkoR is a value duplication of YOZbvWj
# id dhGTHQT is too short
# id 9bgWsJf contains blocked words
# id X94WBY9 is a value duplication of qqs9l3v
# id t9Lgnz2 is a value duplication of KQtiDGI
# id W9DLHSj is a value duplication of M5X50CD
# id LzWayHg is a value duplication of 91NuMA3
# id fFiSxPb is a value duplication of ngAhkE8
# id pKDeQTy is a value duplication of bkjiBuf
# id xIEiQYc contains blocked words
# id uRQviS3 has a wrong format
# id Vz6s351 contains blocked words
# id hiyR6Zw contains blocked words
# id HLHjSS6 has a wrong format
# id HLA3267 is too short
# id zmDYIdb is a value duplication of 0GaqAX6
# id ckwexuZ contains blocked words
# id wae5vAT is a value duplication of ukdhuza
# id 8v3uWyK contains blocked words
# id RQezaUi is a value duplication of AQ9FRP8
# id 09jjwSQ is too short
# id 1WfT5TF is a value duplication of sDOROTy
# id COaLfyG is a value duplication of 6h2RUQ2
# id dMKlAu2 contains blocked words
# id Njmo44t has a wrong format
# id dxcAkkC is a value duplication of vESiAbc
# id d9zUYEN is a value duplication of 8jlSTzN
# id itdZolJ is too short
# id zSVXZIo has a wrong format
# id TODvbQX contains blocked words
# id mIbTYsw is too short
# id HjlLzrN is a value duplication of AI5LptO
# id CUPSN2d contains blocked words
# id l7D75wf is a value duplication of t6ih4Td
# id 9FFA1mP is a value duplication of 0wREsg3
# id 20X72ug is a value duplication of 4RmoMkA
# id CRg0io7 has a wrong format
# id o1rcXdn contains blocked words
# id cgEiOcL is a value duplication of oFVXmbr
# id dakSmPB contains blocked words
# id cVbyEG1 is too short
# id xf3wHHz is a value duplication of rlmTKEV
# id YkrvHD2 is a value duplication of 3zkSYxa
# id aSTsA0d is too short
# id Aomj2xZ has a wrong format
# id 2bvObo6 is a value duplication of feGYmhU
# id sK4XnVn is too short
# id m3Cr3gz contains blocked words
# id wnNVUhX is too short
# id JGwPzhM is a value duplication of 6SsBz4R
# id L1pKU6Q is a value duplication of SfIue4a
# id Bj1y9KO contains blocked words
# id PCle6M5 contains blocked words
# id ZUa31k1 is too short
# id tc2Hgpy is a value duplication of B4KgulV
# id pwXADmg contains blocked words
# id R2n0L4D contains blocked words
# id 4hyKTnZ contains blocked words
# id lg8epdi contains blocked words
# id qVsVyF3 contains blocked words
# id yc0dSrj is a value duplication of nV0IjAL
# id Cx0pG6T is a value duplication of BH0G1nF
# id ANqQG0h is a value duplication of FlUJqkg
# id NDRMAfW contains blocked words
# id Y8qgtyy is a value duplication of qm5BGrH
# id vLwvEzE contains blocked words
# id ApxDXi8 contains blocked words
# id JXyvV2S has a wrong format
# id xiw1Ex9 is a value duplication of 5EE0iWU
# id 08OCMVj has a wrong format
# id pW0pp9E is a value duplication of pVN16Wh
# id 5N2VzLS contains blocked words
# id NwxlO9C is a value duplication of 2vQnvsM
# id yoFet9Z has a wrong format
# id HFj6h7e contains blocked words
# id y1D7NcO is a value duplication of QTWYdSx
# id IBDLMhN is a value duplication of oI0BlEd
# id dckVPFz contains blocked words
# id f0ZkR2F contains blocked words
# id eVAVrTC is a value duplication of QG2mFoD
# id Djgul4I is a value duplication of RbrcJdD
# id iXf3VbT is too short
# id oGjwfHG is a value duplication of UYRQxEN
# id doKZqtS is too short
# id Hie7RQZ contains blocked words
# id bjePWCj is a value duplication of 1kNQtF4
# id Ic6uXin is a value duplication of fS7sxNw
# id eZggrbE contains blocked words
# id WMD5lBL is too short
# id uzyZwQk contains blocked words
# id ya58FaP contains blocked words
# id IeDhFDJ is a value duplication of TmhOBik
# id vd6zeql is too short
# id Oqy9hCX contains blocked words
# id ExMGFCR contains blocked words
# id UlVMiB3 contains blocked words
# id aIou8Qv has a wrong format
# id OhC640V is a value duplication of uWHEZVX
# id cFHMFP5 contains blocked words
# id 4TMomfo is a value duplication of SCk4ZLX
# id GnMhPW5 is a value duplication of v4PzAY8
# id ELFPZI4 contains blocked words
# id X0Ok7Ld contains blocked words
# id SceXo9O is a value duplication of fjwKqxt
# id yqnymWX contains blocked words
# id hmOETPa is a value duplication of feGYmhU
# id HHWmAM7 has a wrong format
# id 0aS7M2O is a value duplication of bvEW8MT
# id 3bAD03T has a wrong format
# id 0KscEE8 has a wrong format
# id DuhXJGk contains blocked words
# id TxKYs2F is a value duplication of feGYmhU
# id IwYUNLX contains blocked words
# id FUGspSU is too short
# id BhpUSQ4 contains blocked words
# id TfzLzCH has a wrong format
# id jNuf4La contains blocked words
# id IxQ8P4l is a value duplication of M5X50CD
# id ORyyhmV is a value duplication of iBJ7yao
# id olxvayt contains blocked words
# id z7LOWoW is a value duplication of oO7lVo9
# id ip0tYDd is a value duplication of vr1Q4Ia
# id YsxALDI is too short
# id 6Fp7z2j contains blocked words
# id HBdUXCh is a value duplication of pKRAr1O
# id Jf2x5pL is a value duplication of JXJbFj1
# id GvS9Rdt contains blocked words
# id XOQEFAC contains blocked words
# id LsKQkoh is a value duplication of 2LotylQ
# id xUIvdyZ contains blocked words
# id iXc9oqc has a wrong format
# id RPKy8I9 has a wrong format
# id 7s96ANI is too short
# id cVk8yhc contains blocked words
# id RXUcaU7 is too short
# id P4YEsRJ contains blocked words
# id ShNTaY6 is a value duplication of bfj6stF
# id IvmABmM is a value duplication of 5e6wU0l
# id Rb7u1MX is a value duplication of v4PzAY8
# id 2a5C19h contains blocked words
# id 6UNgTdc contains blocked words
# id kCZaaHt is a value duplication of lRvvWYR
# id Vy5dH7P contains blocked words
# id 0IcK3Jr contains blocked words
# id BAHXiar is a value duplication of pRpgcNs
# id 2VPGlE9 is too short
# id e245uk2 contains blocked words
# id 7aDxPLO is too short
# id 5hXhJX4 is a value duplication of EFJKKw4
# id 9W5ZM3d is too short
# id 9KmMClu has a wrong format
# id 3N61TTJ is a value duplication of u0tRKZG
# id jf3W889 is a value duplication of WM3NEhO
# id VO6Ruuf contains blocked words
# id KaNFsp7 is too short
# id nLEVEGY contains blocked words
# id AH69oKr contains blocked words
# id lYX75m4 contains blocked words
# id 2CtYTWV is a value duplication of aMqpIOY
# id bYGyheM is too short
# id dBeOLRf contains blocked words
# id 632CDTO is too short
# id ySjoIjR contains blocked words
# id fXLUxS9 is a value duplication of SCk4ZLX
# id 7It3wxy is a value duplication of 6IlbjUn
# id ItEmGrx has a wrong format
# id LEmnAHJ is a value duplication of ELQcQYz
# id uc2BP2K has a wrong format
# id h7qzstd contains blocked words
# id 4KP8Qmr contains blocked words
# id A3q1OPr contains blocked words
# id CvKBXBV contains blocked words
# id eTqxpRy contains blocked words
# id E6eQmW3 is a value duplication of EtU8fLA
# id sMTKV9v is too short
# id GU92jA5 contains blocked words
# id AwfGi51 is a value duplication of agUISUM
# id 6UDZm1H contains blocked words
# id 8COTAKj has a wrong format
# id JAfKWN9 has a wrong format
# id S5AeWBf is a value duplication of CU2tzHP
# id 82Gidls contains blocked words
# id nDMk606 is a value duplication of 0QKjUhI
# id yef7gEk is a value duplication of Kb4iWdr
# id m8xZaIo is too short
# id 7OSNtKz is a value duplication of EJ2L7fv
# id slOAgum contains blocked words
# id DHIEgnP contains blocked words
# id eFIGUby contains blocked words
# id FMFvhHo is too short
# id bvyhaGp has a wrong format
# id XTdfCeq contains blocked words
# id P6I4ktX is a value duplication of NPylPrv
# id YiNdIqf contains blocked words
# id m6YojNH contains blocked words
# id KfaPVev contains blocked words
# id qeRh3sM is a value duplication of NEyNMmY
# id NLlRXC2 is too short
# id 08CqG8m is too short
# id V0ocQKx is a value duplication of uGXh4iw
# id gEpheeG contains blocked words
# id bSKhQNc contains blocked words
# id gMYbuVN is a value duplication of ZT9l10D
# id zcVvENA is a value duplication of MAxRxDG
# id t3CybJC is too short
# id 1fPGI6w is a value duplication of EVxsDXv
# id eFxHzpr is a value duplication of Px5exYN
# id aaTCIeI is a value duplication of UmcOjVb
# id ghEZCUY is too short
# id Abxccag is a value duplication of 3YIWVLq
# id nLvBin8 contains blocked words
# id bPHXCEp is too short
# id 0uvX8UE is a value duplication of cuRrEaa
# id uuemIGC contains blocked words
# id fjCSt5N is a value duplication of zNWsOjZ
# id ijEPzZu is a value duplication of Pznz5GK
# id lOjc3we contains blocked words
# id dsBIeqh is a value duplication of QWJhYvA
# id Q05F5WA is a value duplication of J0LUHqt
# id yab3r15 is a value duplication of iPi2pU4
# id X2jmk2l contains blocked words
# id BprTabz is a value duplication of WTsl6Fv
# id G9znfHN is too short
# id u4isZfD is a value duplication of Unalxq9
# id soYb5Lm is a value duplication of 6V3vJ45
# id npF2Pee contains blocked words
# id 1PIlekT is a value duplication of rjCxCA4
# id u1dbDkA has a wrong format
# id 32bw2G9 contains blocked words
# id v9gC1u7 is a value duplication of xeZB09f
# id 74Lf1rT is a value duplication of OlhSVrJ
# id nYOdp4c is a value duplication of KXK3Ebi
# id fPsjciI is a value duplication of Qjz8J73
# id 3hoQ3OG is a value duplication of 5FHWj0a
# id LVRVExr is a value duplication of Dpmnu8h
# id RZj26yH is too short
# id WPChkYd is a value duplication of 8mQvBss
# id kTvoiwy is a value duplication of KyHdKG3
# id bkzwquF is a value duplication of z9VxpVu
# id 2B8xTQv is too short
# id en6Daqg contains blocked words
# id ZSw1ABM is a value duplication of oFVXmbr
# id hwnaGIi is a value duplication of oq9EFGp
# id CfGrumi contains blocked words
# id mWtaqRf is a value duplication of DOERvij
# id kbADctx is a value duplication of xGmS4fc
# id 1in7ok6 contains blocked words
# id BB0h4Tk is a value duplication of jgqCFKi
# id MsvELPG is a value duplication of 6uoaKyV
# id WTvu939 has a wrong format
# id RYEIOT3 has a wrong format
# id Ony1pAR contains blocked words
# id 6Hwb7w3 contains blocked words
# id kPkbU4V is too short
# id UCVg3jO is a value duplication of SCk4ZLX
# id yok9H3w is a value duplication of RdBdMA1
# id qEshHkh contains blocked words
# id VLAliuT is a value duplication of CGRj1yv
# id nR1I5YX is a value duplication of CIJwIlz
# id EMXNv9s contains blocked words
# id t0Lhtl6 is too short
# id nTR9Lu2 contains blocked words
# id 1jykZNR contains blocked words
# id TZccAn5 is a value duplication of E4DF9ux
# id y2ki1Pm is a value duplication of RyjeRC8
# id pzWw1De contains blocked words
# id Q2N91we contains blocked words
# id 214WcD4 contains blocked words
# id xmXsqRZ contains blocked words
# id 086wupx is a value duplication of uGXh4iw
# id tnVPk4X has a wrong format
# id 0wngyvP contains blocked words
# id jovmmQJ contains blocked words
# id 2O2g1Cq has a wrong format
# id leeclgL has a wrong format
# id GdXduSp is too short
# id r4ViDcS is a value duplication of 96Vr96p
# id xszbp3f is too short
# id 4Xtntlq is a value duplication of SCk4ZLX
# id FbRVgO3 is a value duplication of GhMas4R
# id LI2FGuf is a value duplication of KmGgoEU
# id xJ8WgGI contains blocked words
# id cu83Vv4 is too short
# id QjbGoNv contains blocked words
# id 1G9RSra contains blocked words
# id xE9B5mz contains blocked words
# id wmr6JKL contains blocked words
# id RQPcjq3 contains blocked words
# id zdaCHD3 is a value duplication of 7sgyqkh
# id C4ls2Zt is a value duplication of gwPHZWJ
# id duBC2Y9 has a wrong format
# id 1h9TPxK is too short
# id q2X8x4W contains blocked words
# id anJUI7z is a value duplication of udoQi9K
# id 7Noa8f0 contains blocked words
# id y2sJNTD is a value duplication of WkE2jGZ
# id cr1vb71 is a value duplication of ejhl6W0
# id O5uK1RM contains blocked words
# id u6CnM07 contains blocked words
# id PJqVEf1 is a value duplication of JMW3mYZ
# id h4i3vgN contains blocked words
# id VTJ5R4Z has a wrong format
# id D6JMZz8 contains blocked words
# id aHwvePf contains blocked words
# id MZaYgSn is too short
# id R1mnV6J is a value duplication of GL9ZtI2
# id d64R2e2 is too short
# id jbGt3i7 has a wrong format
# id CfkQLwf is too short
# id 0IMvNnU is a value duplication of tn69iVp
# id IWlNTtc is a value duplication of idDXeXX
# id WdBOWlb contains blocked words
# id nirxG4X is a value duplication of MX0mDVT
# id peaLVvn is a value duplication of 2OYRgHJ
# id Bo9PMfS contains blocked words
# id nb9am3z has a wrong format
# id dwsWDDN is a value duplication of btDdmSQ
# id GN4jVgL is too short
# id X14tg0t is a value duplication of ffnxXFx
# id 0zwsLh6 has a wrong format
# id Kuq5rsZ is a value duplication of HthIr44
# id rcrfHrN has a wrong format
# id LRrnT93 is a value duplication of nQotFsv
# id FpVjnpO contains blocked words
# id sRMGef8 contains blocked words
# id Kk4t5oL contains blocked words
# id a58o7m6 is a value duplication of QxmO1vt
# id LMfZj3g is a value duplication of MAxRxDG
# id EnV5rv9 contains blocked words
# id fH9hsvE is a value duplication of k5HzBL1
# id NqeoSOC contains blocked words
# id jgUnXvi is a value duplication of H5xMcOZ
# id 54P4PZ3 contains blocked words
# id IJ1TcWC is a value duplication of O8djord
# id OLj8emn contains blocked words
# id 3kcJhaf contains blocked words
# id nhAxyO1 is a value duplication of B11OrHK
# id G5jSZNL contains blocked words
# id JTceZLY has a wrong format
# id Z3vLMgX is a value duplication of WTsl6Fv
# id eLFgfBg has a wrong format
# id twZR5C2 is too short
# id H6MwbDV has a wrong format
# id Jk5l8tC is too short
# id QqI523V is a value duplication of TpQD25E
# id wSNjvQ0 is a value duplication of gSYBs5q
# id mEXKKOY is a value duplication of GQmiQkA
# id rT0SYPM contains blocked words
# id 81cQWb2 is a value duplication of OMLdETK
# id 0AFDW9x has a wrong format
# id fLDZQ3F is a value duplication of xHNNsgY
# id 1NVVe1Z is too short
# id bcS0fTd contains blocked words
# id 2mSw7WM contains blocked words
# id Etg4yRg has a wrong format
# id KP1Zzj7 contains blocked words
# id lj99eOs is a value duplication of d3S830d
# id UHntjKe is a value duplication of yb6E37F
# id Kaoyt3o is a value duplication of 91NuMA3
# id 1ONbNtf contains blocked words
# id NwLWvqA contains blocked words
# id BbIiAwE is a value duplication of 21fXhOk
# id hlG66Si contains blocked words
# id S0mG9La is a value duplication of xVLCiCX
# id Hmu657L is too short
# id y2xq7gy is a value duplication of EMwYwle
# id mo7T7Au is a value duplication of 1UbFgu2
# id zJtW0XK has a wrong format
# id VfVRKLH contains blocked words
# id j4A4pX9 is a value duplication of 8hGglZF
# id bLv7JMf is a value duplication of aUBDhxx
# id 5vo4j3Y is too short
# id fs50Gan is a value duplication of O6NO7Vo
# id dp1TbbU contains blocked words
# id AH6Qj0k is too short
# id 9kq9OjR contains blocked words
# id NYZuzf4 has a wrong format
# id Ark2mva is a value duplication of FQVzP6R
# id p6dLezP contains blocked words
# id doDI08x is too short
# id JKB0KpL is a value duplication of yzPwqBS
# id iZMW417 contains blocked words
# id oJCqL5T is a value duplication of CV2VE2Q
# id RPK3qQh contains blocked words
# id BwhoB1I is a value duplication of sAlV9iW
# id rccyMLV contains blocked words
# id hZX7l3T contains blocked words
# id zdRhBqU has a wrong format
# id 0ry6MOV contains blocked words
# id D68WsKu is a value duplication of F2IYNhs
# id YJyogQJ contains blocked words
# id pmpZY3k is a value duplication of d7bP5fb
# id WKHZD25 contains blocked words
# id R99IMdM has a wrong format
# id nGl9J0e is too short
# id sytH6IY is too short
# id Hs0lMW4 is too short
# id EfIlWFr has a wrong format
# id fAdQtwW contains blocked words
# id KFHpRhD is a value duplication of hh6BIhB
# id NV0rwPo is too short
# id vNzpcUy has a wrong format
# id Dfmb0w9 has a wrong format
# id FfxWZ49 is a value duplication of 0dscgSe
# id pBzKKmA is too short
# id jyoaj1B is a value duplication of 4iZRmH7
# id QBahobV has a wrong format
# id Nuletg2 contains blocked words
# id rRVOBnd contains blocked words
# id DVofCDy is a value duplication of v2Ygaid
# id Rr9z1jW contains blocked words
# id wh7HaPj is a value duplication of aMQ6wLJ
# id 3PUdX2U is a value duplication of brc2wJS
# id lsr2Ysf contains blocked words
# id rTo14YO has a wrong format
# id 6poO9nA is a value duplication of MOpCbrr
# id kfhzhkP is a value duplication of kDooEVH
# id eehR5Wk is a value duplication of cxq3ynb
# id F8ZZ2gv contains blocked words
# id clZrN0v contains blocked words
# id kgq5Pz6 contains blocked words
# id qTGCeQI contains blocked words
# id 5Xrykvp is a value duplication of qNh37SC
# id AE3smx4 is too short
# id xuwbyFX is a value duplication of JyHTgx9
# id L0iMweZ contains blocked words
# id 1h5c52t is a value duplication of v2Ygaid
# id DeBCTgs is a value duplication of qqs9l3v
# id JDZw9Q8 has a wrong format
# id XX7PlJ4 is a value duplication of rr03IeY
# id fwVRwbf contains blocked words
# id lvMAb9Q is a value duplication of ZxKOPCw
# id Rqdqsjp contains blocked words
# id 7zMkRIR is a value duplication of 8unWSFr
# id G6VO5ZL contains blocked words
# id 7YuT6FX contains blocked words
# id BVeRVEX contains blocked words
# id OaLtzor contains blocked words
# id 1spX0sU contains blocked words
# id ChTYzi9 contains blocked words
# id cr097L4 is too short
# id 7sXnEN5 is too short
# id MokYdt7 is too short
# id GEMb8mN is a value duplication of bhMhBxT
# id JuB2vrP is a value duplication of NEyNMmY
# id NwpvtaT has a wrong format
# id n0CwUzU is a value duplication of 9jYqFJC
# id 18GaKOg is a value duplication of cNgFd6b
# id rPqR9ea is too short
# id J20NRk3 is too short
# id 7gyoG3h is too short
# id b0CsaZK is a value duplication of FvmYXYs
# id 2Qpo9KI is a value duplication of 5B9A9jW
# id TA6f7Gl contains blocked words
# id ZnJIi1Z contains blocked words
# id seX9L9x contains blocked words
# id 1n6DHXg contains blocked words
# id sX7CPy6 is a value duplication of SCk4ZLX
# id HjbYGk8 is too short
# id oAnAwKk contains blocked words
# id gU84l72 contains blocked words
# id 3TCmI8u is a value duplication of RiDVV7E
# id eS4l7Tl contains blocked words
# id wJ8NtYP is a value duplication of 5UenmXO
# id yFzunUn contains blocked words
# id olbxfL0 is a value duplication of ehOiwq3
# id efXU8Gb has a wrong format
# id rlTbZL5 is a value duplication of BsJmrUB
# id Sos2HV5 is a value duplication of qDIYQd5
# id bCeRewK contains blocked words
# id i2sNpwi is a value duplication of ZVPWPhP
# id Yz7gxro is a value duplication of U4aebJO
# id DVknLTW contains blocked words
# id SF1zvi1 has a wrong format
# id 15gZrBb is a value duplication of HITflT0
# id xUTeP4s contains blocked words
# id U8VKsiR is a value duplication of R6jaN1b
# id hKeOtB5 contains blocked words
# id e9zX2I5 is a value duplication of mAOYbXZ
# id Q4UF9Yf is a value duplication of ZDTGCug
# id fFcRaJX contains blocked words
# id 8SFdxly contains blocked words
# id 4k4RoHL has a wrong format
# id Jl7PKTi has a wrong format
# id 1dPtTez is a value duplication of ylUoCwU
# id 4uUOv1q contains blocked words
# id x4j13Nn is a value duplication of 3kTwXE9
# id 5xJFUbS contains blocked words
# id FAb0oIE contains blocked words
# id N5RelPw is a value duplication of jOGVJoz
# id p6NLC31 has a wrong format
# id QJXIM1E has a wrong format
# id 3eXoK44 contains blocked words
# id a1D0HVy is a value duplication of kyfKpBM
# id tYbBoG3 is a value duplication of hJzG6Lf
# id HNLZpMJ is a value duplication of AkE8VzB
# id 3ctWSWY is a value duplication of y9ryqUw
# id UGqgD4Q is a value duplication of Jqu3FLW
# id 3ocWCwI is too short
# id Ykl8o6Q has a wrong format
# id 1SZcdUC is a value duplication of WLyF7bM
# id 5sZIoMp is a value duplication of 9Ix050J
# id IwocB4Q is a value duplication of SN75UkT
# id DCwZhYi has a wrong format
# id zdstbjL is a value duplication of eWm0Uvs
# id fqKHG1n contains blocked words
# id CKIdXYL is too short
# id jZLIIGe contains blocked words
# id Pn7fsYf has a wrong format
# id 5xFspx3 has a wrong format
# id 1dbLMgC contains blocked words
# id 1q9ieS7 has a wrong format
# id 9xYKJPX contains blocked words
# id 1r2UgQc contains blocked words
# id J58YISb contains blocked words
# id JVUDvum contains blocked words
# id ke4bzf4 is too short
# id ug7pcRG is a value duplication of L0JQemN
# id h0un5Rm is a value duplication of O3FeoHQ
# id aswzeM1 is too short
# id 7YIVG2v has a wrong format
# id Ie2gs8Q contains blocked words
# id UPsNfzS is too short
# id 0Jd1M1P is a value duplication of AAyIOD8
# id 5T1MCSF contains blocked words
# id HIdxm2l is a value duplication of 1ImBtmh
# id 4Ikw4iW is too short
# id JiscE9P is too short
# id s9TxtJg has a wrong format
# id 6dPu1r4 is a value duplication of 40qcQLS
# id AzCJFXG is a value duplication of S8gExpS
# id dM8Afgs contains blocked words
# id hxeOczl contains blocked words
# id 6RWAV6V is a value duplication of UJm9G1y
# id PgWTzIx is a value duplication of dkgOj94
# id H2LcgCO contains blocked words
# id gNQujrM is too short
# id XlNs8Lz is a value duplication of ikXPrLF
# id gmQ5U73 is a value duplication of dfJACtG
# id qaRIhkl is a value duplication of jb0Jeyf
# id jrLfIuk contains blocked words
# id w4EFcsN contains blocked words
# id 3abODoA is a value duplication of UjmVbDm
# id 3Zp8xbV contains blocked words
# id KvIRcl5 contains blocked words
# id LiDwJ12 is a value duplication of PIwT1bi
# id Wk1N4M2 is a value duplication of tZIzrr9
# id TdAQAoD contains blocked words
# id 1QO7XBU contains blocked words
# id d7KTckY is too short
# id nE58PYV has a wrong format
# id G371aBF contains blocked words
# id LiY4vsn is too short
# id 2GIF5Yp is too short
# id wqc0wLk contains blocked words
# id udmsDvw is a value duplication of MYvoaFu
# id rCpVay4 contains blocked words
# id JUtyCgw is a value duplication of oQ9uSDb
# id WvVK2no contains blocked words
# id jSpQXK1 contains blocked words
# id nDnxOVV contains blocked words
# id v1OGeHo contains blocked words
# id q6zxQmv is a value duplication of 1qGj0rp
# id s9bussC has a wrong format
# id 4BnHwoP contains blocked words
# id fFRgo7C is too short
# id 9byh3zo is a value duplication of IMl2Zdr
# id SiRBR13 is a value duplication of Dg54otn
# id PEHHSeH contains blocked words
# id VR827zs is a value duplication of i92muAi
# id csnyo7T is too short
# id sNY4gWn is a value duplication of lQIR0I0
# id txM2uOV contains blocked words
# id 3fjWnZq is a value duplication of YpleI8A
# id 9VSEPcD is a value duplication of tBjKvWQ
# id aMmUfVH is a value duplication of eoJwAWu
# id xfCR7Rl has a wrong format
# id Q2CAUd7 has a wrong format
# id dpIv6cU contains blocked words
# id msGOMvR contains blocked words
# id EhsqiDT contains blocked words
# id UN3IlLX has a wrong format
# id ob8zVEV contains blocked words
# id IaeUGk4 contains blocked words
# id xJQogSf is a value duplication of 5GvGKCQ
# id u6HLZz6 is a value duplication of cp1RgPe
# id 92Xud5V contains blocked words
# id fmm71Gf contains blocked words
# id pdX8OQz is a value duplication of P7wC7Kp
# id buXamwc is a value duplication of ZmObpjG
# id OmtQqos contains blocked words
# id EeIKG9s has a wrong format
# id Fyp5UJ0 is a value duplication of vRkueLp
# id mirbMzv contains blocked words
# id kxslIww contains blocked words
# id ipHLI13 is a value duplication of MztLCYm
# id kS7TiOd is a value duplication of 2Qx43E3
# id MNeKKcS contains blocked words
# id dw8356w is too short
# id zZd6rCN contains blocked words
# id l6vmJZt is a value duplication of NEyNMmY
# id mipmAhr is too short
# id Lr9WAjt contains blocked words
# id niBiweD contains blocked words
# id oyWLMSq is a value duplication of MbzP1iS
# id 2MZR9RX has a wrong format
# id fRjPedx is too short
# id 4Umrmb2 contains blocked words
# id rioL4gP is a value duplication of aGZcXzO
# id smSRWIf contains blocked words
# id MzZN0lh is a value duplication of MQ0x9x8
# id zkiQT9S is a value duplication of bbMn7Lw
# id R7llPkj contains blocked words
# id uZ56RpD contains blocked words
# id nnXQI1y is too short
# id HSFSAXe is too short
# id kP6GEZy is a value duplication of 4AzPTRS
# id 2Qw22hH contains blocked words
# id FCNWk0K has a wrong format
# id e3OA997 is too short
# id Vjkqc5J is a value duplication of bkhQO05
# id K5xv4lK is a value duplication of E3qOjR5
# id 3ynPDRt is too short
# id e37svjz is too short
# id XAvbgnC contains blocked words
# id KIm5nM5 is a value duplication of gVq6MMX
# id NEKMgyI contains blocked words
# id BqLu9ae is too short
# id pP6uafE contains blocked words
# id t7TyN7n contains blocked words
# id V6PyKZr contains blocked words
# id WoFsPMp is too short
# id 3KSeiJU contains blocked words
# id 2C0la52 contains blocked words
# id CCsN6QC is a value duplication of aUBDhxx
# id oLHkO7u is a value duplication of nmS7Qj4
# id M9V3r2k has a wrong format
# id KyPVkGT has a wrong format
# id EnDWGW5 is a value duplication of tZIzrr9
# id bx8kAND contains blocked words
# id 5nO7j1J is too short
# id bUmPOZ3 has a wrong format
# id GS379rf is a value duplication of FaLyx1y
# id Hs1q9i4 is a value duplication of uls1XEF
# id HYI3HgX is a value duplication of sfofrkM
# id tXHcUA8 is a value duplication of pGuXDJ6
# id 3TtgmoK is a value duplication of 6qcDOYo
# id N5rxLiv contains blocked words
# id 1u8UmwC contains blocked words
# id okLzRjD is too short
# id hXKynr5 contains blocked words
# id 8WuTvUX is too short
# id qhFmMN5 contains blocked words
# id 71AYytz contains blocked words
# id UH8cJfN contains blocked words
# id hPfom9l is a value duplication of Gxjkb1K
# id npfd25W contains blocked words
# id nuTQ3JC contains blocked words
# id pnlwrSl contains blocked words
# id GZBonRv is a value duplication of J8OZv8f
# id v5ei0RF contains blocked words
# id jMDOdC3 contains blocked words
# id NwUxSNY contains blocked words
# id KnAehHV is a value duplication of RwCpz6t
# id Y2eitOR has a wrong format
# id 5EvqgqN is too short
# id 92lGB2R is a value duplication of tb0gGE4
# id aCSJE8s is a value duplication of t5aPL0s
# id Tx50WxM is too short
# id nTbVdIL contains blocked words
# id zVCDiVw is a value duplication of scfUPpe
# id eFAbgLv is too short
# id C1yNJ82 is too short
# id k5xEfy6 contains blocked words
# id RucdicB contains blocked words
# id nA0KWHb is a value duplication of rj6tm3z
# id Mls7FGu has a wrong format
# id edzH8Ac contains blocked words
# id ISDkiin is a value duplication of sNbCkfL
# id 4Fqz138 has a wrong format
# id 9F9gyru contains blocked words
# id HVJnIiE is a value duplication of DCIJh4H
# id 16i4Iyy is too short
# id fWqgyaj contains blocked words
# id 3q7rB3z contains blocked words
# id m2xPr1G has a wrong format
# id Xtwbx4s has a wrong format
# id sZkqA9F is too short
# id E3FiZj3 is a value duplication of naqWC8Y
# id z4AQjnP is too short
# id qjvBuRG is a value duplication of SCk4ZLX
# id MOGvXXj contains blocked words
# id p7hTgsz is a value duplication of 8j6pKOA
# id AexR5PG is a value duplication of DCRoZFF
# id 24RQXz6 contains blocked words
# id GLfHRJs contains blocked words
# id 9roQp6s contains blocked words
# id 0k03Azt contains blocked words
# id 30Jmlun is a value duplication of NYTOglC
# id WELanRt is a value duplication of SHFBhAT
# id OkIbQbv is too short
# id p0lw45d is a value duplication of zCZ5L7m
# id n3kgf14 is a value duplication of ucYcRzo
# id LfLDcIe is too short
# id Vh9jBhP is too short
# id 69MJdNb contains blocked words
# id xWVj4kv is a value duplication of qRnLLZD
# id yWPQOy9 is a value duplication of GgimvDI
# id R19dNWR contains blocked words
# id UpgqKEQ contains blocked words
# id KicbzAk contains blocked words
# id l9OiW84 is too short
# id ctRapP3 contains blocked words
# id WbPDvIX is a value duplication of 9rlUuSq
# id eFTPAPr is a value duplication of 5OlXYmR
# id O3Obw33 is a value duplication of Npujosv
# id tvcY0lQ is a value duplication of npnhOAc
# id RDDrlQT is a value duplication of aNEfjdq
# id gmwsw4b is a value duplication of K2hVMdO
# id ZpUetAJ is a value duplication of lPJcx9n
# id pakDAwi is too short
# id j6eOAEA contains blocked words
# id QfsMJrD contains blocked words
# id Df1wZ7J has a wrong format
# id jivnoBW is a value duplication of JggTkJe
# id FfH0OS3 is a value duplication of MbikOgJ
# id nMMvXz6 has a wrong format
# id d3SBjmr is a value duplication of x2GpAUU
# id f6SJBXr is a value duplication of 07MHR6h
# id DK09Wjp is a value duplication of 67laIq2
# id zZPWQoR contains blocked words
# id NYROy0b contains blocked words
# id wTYFM18 is a value duplication of mjRpqZN
# id hXv9xSB contains blocked words
# id 93e9g2C contains blocked words
# id 9gecoRl is too short
# id 3HIhZzI is a value duplication of dfJACtG
# id h4HeAJ0 is a value duplication of J0n6UJC
# id yBzLoGd is a value duplication of jNcjTAw
# id XiljYiZ is a value duplication of vTYRaPr
# id dmnML6i contains blocked words
# id YC2zWmn contains blocked words
# id ySNZRgI has a wrong format
# id sDfu38Q is a value duplication of TU4Eq7G
# id fkBf5KL is a value duplication of SCk4ZLX
# id GUHeADT contains blocked words
# id kaQIQcg contains blocked words
# id 7jcumpo is too short
# id YPBeZt4 is a value duplication of Bu6kVp4
# id e7E4H6f contains blocked words
# id IDSM2aj is a value duplication of AOlktMk
# id MQe6N1e has a wrong format
# id PhIAqlM is too short
# id orXCJgE is a value duplication of SCk4ZLX
# id dHTpdbK is too short
# id ooWw3kH contains blocked words
# id TpH3VK0 has a wrong format
# id vwtBk47 is a value duplication of R8aI4qg
# id AKi6v7N contains blocked words
# id bEmeMVP is a value duplication of 4l9F916
# id UFLZFnX has a wrong format
# id ZtA6XmG contains blocked words
# id 2CzEHvL contains blocked words
# id KnlXZUN is a value duplication of aAOzPk2
# id 1OLVi9H has a wrong format
# id H8EI9BT has a wrong format
# id p0tNHhY is a value duplication of JzX5c5N
# id FPU6Oav is too short
# id Hzmkg00 contains blocked words
# id h8nh892 is a value duplication of RvfXCLs
# id nBzQPFp is too short
# id gr0d4eD is a value duplication of 8nFbAmh
# id AjjnPAb has a wrong format
# id yP2QBjg is a value duplication of DDnUhPZ
# id igVT4sk is a value duplication of vO6fFpN
# id WKEVIZ6 contains blocked words
# id fOez44S is too short
# id cDlYqSf is a value duplication of O3FeoHQ
# id ryK1pCs is too short
# id 6N8vbVc contains blocked words
# id FEZaoQ6 contains blocked words
# id BF0Wq0M contains blocked words
# id ufcJMkI contains blocked words
# id 2GQCMDg is a value duplication of AzIfMEU
# id iKjpJbP has a wrong format
# id wZ57zyY is too short
# id AlX6EcU is too short
# id GRmrltv is a value duplication of qKdaqN0
# id b6YvWGs is too short
# id gBX8xIe is a value duplication of bRAeF6v
# id 0qWlLsS is too short
# id F8vptoL is a value duplication of 8W53rTt
# id p1Njd8B is too short
# id IUieskM contains blocked words
# id 3BqiVjM is too short
# id vZFxg0B contains blocked words
# id 9DKEHTf is a value duplication of OkrPUSx
# id AjxScEf is a value duplication of rIkmcns
# id j8FWGI6 contains blocked words
# id lrWlXyu is too short
# id kholNHS is a value duplication of tpdSu0r
# id 1ZHZ3qT is a value duplication of AFU7lyN
# id HjRAm6Q is a value duplication of PCENI3h
# id FXXR3FY contains blocked words
# id 1wraTaJ contains blocked words
# id GoseZGE contains blocked words
# id EQ0EGCh is a value duplication of J6hOJZz
# id Eg6rulP contains blocked words
# id RJhkQLp is too short
# id nuRNmYU is a value duplication of 9QQieo5
# id rHd2uxQ is too short
# id 5GXswtv is a value duplication of feGYmhU
# id JEkScDY is a value duplication of hV2NEYj
# id SXBFMQo is a value duplication of WnPaRVp
# id Fi5UpOu has a wrong format
# id mucMk79 is a value duplication of C8vFT4L
# id tecl2gU has a wrong format
# id gzxWlCX is a value duplication of 4NgfB4L
# id bF3zl1Z contains blocked words
# id f8ePInC is a value duplication of B7EVZgs
# id 32Grzqr is a value duplication of qnBsqq1
# id 2K8stMJ is too short
# id Y86BYEJ is too short
# id 2zxN4lc is a value duplication of IXdMGrm
# id g274nVc has a wrong format
# id Y4HDCUl contains blocked words
# id QFwO12V is a value duplication of zJnIKYL
# id WLrhxeg is too short
# id nzxMX3e is too short
# id 2GYBuIS is a value duplication of NKmJnIp
# id eIltAja is a value duplication of F19qjV0
# id EZjMZ7M has a wrong format
# id jxiBGQl is a value duplication of CYRxCt5
# id xIYPIiY is too short
# id dzB3vxx contains blocked words
# id u2Mo073 is a value duplication of EHcOZTe
# id LmaDElN is a value duplication of LOkoBDx
# id afflVeZ contains blocked words
# id lPvVO30 is too short
# id 9bDq8OE is too short
# id XKSN1Gf is a value duplication of 3ACOWLv
# id G4FYAa0 is a value duplication of BFsAO1H
# id aClvoXL contains blocked words
# id ONuDixr is a value duplication of SHUmfSm
# id c23fYUT contains blocked words
# id niv3kht is a value duplication of 3mxyniz
# id wbWZqLd has a wrong format
# id Lv429ZX contains blocked words
# ...
# id UcX0eIE is a value duplication of kGjoR0M
# id w9oYnGq is a value duplication of gZi18be
# id fG0xeei is a value duplication of RnMvNC9
# id mWDAXfw is a value duplication of Qz3OYEf
# id aBGZbmc contains blocked words
# id sPGePXn is a value duplication of DKxASjX
# id aLXyE1B contains blocked words
# id UxhmTH8 is a value duplication of learnsv
# id F8k9pr7 contains blocked words
# id pMrWuFo is a value duplication of aNqhroH
# id IhIlQC7 contains blocked words
# id Ye88IWf contains blocked words
# id tHuUIhl is too short
# id zR5pWDu is a value duplication of Cr8YiR8
# id qY0gAR5 is a value duplication of eO6pKTM
# id 09Qohac contains blocked words
# id lA4YE5e is a value duplication of wb0UmCn
# id waRQ5Me contains blocked words
# id Z9c4ozR has a wrong format
# id OUjI2KS has a wrong format
# id hbmaYCP contains blocked words
# id CEEVUfe contains blocked words
# id Dc13BAX contains blocked words
# id seZfvtp contains blocked words
# id KhiiTRH is a value duplication of 5M8dlRL
# id 1QNppIE is a value duplication of YLyx3Tf
# id o0Abf3S is a value duplication of mXeqBzQ
# id YNR3VV2 is a value duplication of oZZOJkw
# id LmFx3O2 has a wrong format
# id 5zYN0hV is a value duplication of 8UG2K4a
# id D7iPF15 is a value duplication of 3QVEYx4
# id GiWo7De contains blocked words
# id MG99U5B is a value duplication of lMPhamz
# id OOAiMpS contains blocked words
# id pdCnKzr contains blocked words
# id nbpFD77 contains blocked words
# id 87vAhix contains blocked words
# id MGTdZtH contains blocked words
# id feBPdBd contains blocked words
# id KsLr0uF is a value duplication of 2l21JKz
# id fN1OUSP is a value duplication of EpqGzgA
# id jKt9UO5 contains blocked words
# id Ywea1mq is a value duplication of UTwO5oT
# id ddzQUQw has a wrong format
# id D1A36Un is a value duplication of 1pBFOQr
# id 8H9imgT is a value duplication of yj7KPNe
# id 9POJqnq is a value duplication of B9dd4nH
# id cev2AfN contains blocked words
# id TfIULs2 is a value duplication of GhoEp9t
# id 3LnRWkp contains blocked words
# id RNC3Mvx contains blocked words
# id 2HkRljH is a value duplication of Y2txQDK
# id 76NoQRK is a value duplication of tllwvjA
# id PWmVYFK is a value duplication of Z96hIHr
# id UqMkacx is a value duplication of HNPHVhy
# id FDsWvo1 is a value duplication of ybLbqua
# id 911nhbN is too short
# id ABIFQXU is too short
# id 5FoTT30 is a value duplication of B16RWYL
# id Zkx1ukJ is a value duplication of zWauOni
# id b7bfUNH has a wrong format
# id XOxYclt contains blocked words
# id 4SsJb37 contains blocked words
# id fmkAtje has a wrong format
# id M80wSMV is too short
# id IL6Kxta contains blocked words
# id 5Up9auW is a value duplication of L8iN35D
# id ijZ2Bps is a value duplication of DrRCzIv
# id iIUmUO0 is a value duplication of 1qI3kKV
# id C8OoDnM is a value duplication of gz8RIwZ
# id XYwLDZs has a wrong format
# id EQulnYz is too short
# id YGEzsCG is a value duplication of uIajR0f
# id Lsld05J is a value duplication of QeoiBM7
# id JRLEE8d is a value duplication of BWBKbQU
# id 2KGSAEm is too short
# id 2znCgcE is a value duplication of SQxi23C
# id qrGnvYr contains blocked words
# id o3UX5dJ contains blocked words
# id Ca4s6LY is a value duplication of vewxHSn
# id 8Iccs0g contains blocked words
# id IXhGrVw is a value duplication of Ku6UE63
# id mKBSA97 is too short
# id 2Rms2zN is a value duplication of 13VyV6c
# id O3vJk7H contains blocked words
# id YBoyU3X contains blocked words
# id TN9xQk8 contains blocked words
# id 6Aoo90Z is a value duplication of m2oCc53
# id Fu7gFgJ is too short
# id 2bSArUG is a value duplication of vESiAbc
# id u7Vl1wF is a value duplication of irsAoFB
# id CCZZUAm contains blocked words
# id TefglTF is a value duplication of wyXFnQr
# id 7C02xP4 is a value duplication of jTWhGLX
# id Cg7ohHi has a wrong format
# id C45Mc56 contains blocked words
# id bpygFJk contains blocked words
# id 0KqNWTa is a value duplication of M5oHP82
# id Hb5sNDD contains blocked words
# id 2l6hVGP is a value duplication of HxbRWQ3
# id 9hbZVWN is a value duplication of iToe0vO
# id SbzzVZt contains blocked words
# id vcDSyGO is a value duplication of ZBw6trM
# id BKy9wVe is a value duplication of EehxB5H
# id w9AufNJ contains blocked words
# id nqBO3fR is a value duplication of z3j5S5T
# id 0oKMR2b is a value duplication of SCk4ZLX
# id skuuYph is a value duplication of DN2uoD1
# id XPePOYA contains blocked words
# id VK3ofIq has a wrong format
# id pAV0wXF contains blocked words
# id wqIuesm is too short
# id u8rotYl is a value duplication of Pj7d7vS
# id bJh9LPd is a value duplication of xpUOb1v
# id I1t6PRK is too short
# id YMRL7nf is a value duplication of Ruhs9rX
# id KvM4VVi is a value duplication of h7wCSEp
# id NFQrN4Q is a value duplication of gtwEnqt
# id hJLllWE contains blocked words
# id H2ELWTJ contains blocked words
# id PUtdebg is too short
# id Ufei2dQ is a value duplication of Xf5RqiV
# id u1FlPty is a value duplication of boLuV1d
# id muLMPNp is too short
# id Ni0HzKD is too short
# id 4RdLYpi is a value duplication of U9p2NFJ
# id fov2Pup contains blocked words
# id toAIh2i is a value duplication of ZQXLDUw
# id igyHkLT is a value duplication of fmeRm31
# id 4Zta5QK is a value duplication of TzX0dAR
# id idFcjwm is a value duplication of 2phN000
# id ayjjYJk contains blocked words
# id WetAHhj is a value duplication of JDBsYcI
# id 6yEdSXk is a value duplication of xFOGGTt
# id X5lKzzD contains blocked words
# id 5tlnDCw contains blocked words
# id XjZKBtm is a value duplication of BR8q0Th
# id p4vx1gL is a value duplication of tK79lr3
# id M2rlNAD is too short
# id aAIbSQp is a value duplication of xAoIBKg
# id nffZVPx is a value duplication of S2SoDY4
# id 9zfwbYs has a wrong format
# id RrXfJiK is a value duplication of k5HzBL1
# id RsLMBLr is a value duplication of yjMXiHS
# id cNR1pml is a value duplication of xFOGGTt
# id ROKodd1 is too short
# id 3kB0gT0 is a value duplication of JdldzaB
# id SzxdYEK is a value duplication of qKUwVLy
# id OREtbSi is a value duplication of E3ZyTza
# id IaVFLMW contains blocked words
# id mp4lduu is a value duplication of JTyxR1P
# id Vt3rUNK is a value duplication of 7Uo0hNj
# id GHg4pXd is a value duplication of 8a6K0Ju
# id xL1Qv3b contains blocked words
# id Hs8bd1u is a value duplication of 5MK1O7x
# id qqWsvlQ contains blocked words
# id NCdqvFp is a value duplication of Lr5KKpM
# id vNE9UDU contains blocked words
# id CqZ6ESE is a value duplication of BpuvKkT
# id 0VCpJvy is too short
# id fGvhzDq is a value duplication of p3d4gIV
# id lDjJYUP contains blocked words
# id DAr2SHr is a value duplication of xFOGGTt
# id lBy3JvF is a value duplication of q5JXqaR
# id sZu1bIE is a value duplication of j204MR7
# id 0wcEIHD contains blocked words
# id ygPWfVZ contains blocked words
# id KwQpIkp is a value duplication of hzXCO3t
# id n8jQ2vE contains blocked words
# id j0gx4dg is a value duplication of XJrSZde
# id fJ1x93y contains blocked words
# id tPL4LpM is a value duplication of proG6KP
# id qqF8UpT contains blocked words
# id TTXu3Za contains blocked words
# id iXrdctd is a value duplication of XkwUKSq
# id 8b3MPM2 has a wrong format
# id 90O03jM is a value duplication of Sj60FCy
# id MfCZxit contains blocked words
# id 9VShvAx contains blocked words
# id l7TAfR9 contains blocked words
# id ELl0RFC is a value duplication of gyNAJdL
# id JuuOQaw contains blocked words
# id nIlWn2S is a value duplication of 8DdAIM6
# id 1Tjumaf is a value duplication of ekPLvv7
# id xg59iqY contains blocked words
# id bLazM5K is a value duplication of BfzLouc
# id 6fvKuwL is too short
# id hlD4lc2 is a value duplication of C1tXeiQ
# id lFCIafY is a value duplication of J6hOJZz
# id aWCQqsV contains blocked words
# id qRM0vr0 is a value duplication of ikXPrLF
# id AIRwNHf is a value duplication of unMT15I
# id l8poF2t is a value duplication of ZDTGCug
# id fGzIi1W is a value duplication of dwAhAhV
# id I149njV is a value duplication of ucYcRzo
# id zWIyIiP is a value duplication of 1aXQ9Vy
# id wKeQ5ce contains blocked words
# id ozfbD4i has a wrong format
# id fpyPr7d is a value duplication of g3TuOsS
# id gkuSrgK is a value duplication of CgnFAMU
# id GDzajZq is a value duplication of x06VK9A
# id VDy7IaK is a value duplication of 0QKjUhI
# id FFuo6Eo has a wrong format
# id wkZcWVd is a value duplication of 6ObOZhW
# id M9d05Xm contains blocked words
# id Rwei10r is a value duplication of Pj7d7vS
# id Vq2WDRZ contains blocked words
# id yzd6bsv is a value duplication of aEPwcEV
# id cqIw4rb is a value duplication of XJrSZde
# id h8RilIN has a wrong format
# id ahwQYc1 contains blocked words
# id 0ht9Ejh is a value duplication of AnSPdb1
# id DwuotGr is a value duplication of tjvHbRE
# id G3u7E03 is a value duplication of X3THxPM
# id xmVlDjd is too short
# id doGOMR1 is a value duplication of 9kBp2Qr
# id sMHjje1 is a value duplication of N1Bdvko
# id Eq2mDfv contains blocked words
# id 24soeWm contains blocked words
# id mEZQcsx is too short
# id 2WU7SKF contains blocked words
# id 3NDzK1y is a value duplication of C1s61jv
# id Fstb3BI is a value duplication of ASZIXD4
# id bXEotYi contains blocked words
# id lQFqpkW is a value duplication of InpElqr
# id W7YWPeL is a value duplication of xFOGGTt
# id nRU67Ld is a value duplication of nLzJcse
# id jydMdJl has a wrong format
# id bQHxlVP contains blocked words
# id GLKEwIG contains blocked words
# id N3ijDxT is a value duplication of DAqgjic
# id KqhQc5o is a value duplication of 63rlBR6
# id BjOyuJb contains blocked words
# id ccezlsL is too short
# id v3G0Nfs is a value duplication of SCk4ZLX
# id cfHA2H7 is a value duplication of m0rmnXr
# id rJcvsH2 is a value duplication of HL0WMML
# id GQRm8lR is a value duplication of MBtdlHl
# id Y0UCfdp is a value duplication of o2E0yDT
# id hmzbsvJ is a value duplication of o6IHWFb
# id CWJxlZg is a value duplication of 0TZ7Nrz
# id wNxHEUE is too short
# id x0bn4qI contains blocked words
# id jO31LU5 is a value duplication of f1CVb94
# id io5uSMZ is too short
# id jguUp6J has a wrong format
# id 31tIZbH contains blocked words
# id jCI2gcK is a value duplication of fEkVs2N
# id fDN4N36 is too short
# id 04nYDCQ is a value duplication of oSKqUWa
# id 47xgreA contains blocked words
# id kzLOktK is a value duplication of 7IS52NH
# id P1RbLxL is a value duplication of khovH8T
# id baIjYly contains blocked words
# id a6Y95Y9 contains blocked words
# id DsGf1To contains blocked words
# id ciNRM0i is too short
# id YmYvYkZ contains blocked words
# id jFNHXYM contains blocked words
# id 48rPEop is a value duplication of wMnrFZu
# id eJyhT7r contains blocked words
# id TFYMyep is too short
# id AH4KqzY contains blocked words
# id uJGzi96 is a value duplication of muudIF4
# id nGKg7K4 contains blocked words
# id CFYSmar contains blocked words
# id F7dWjKl is a value duplication of bX1Lauw
# id A7AwKfH is a value duplication of SHUmfSm
# id BenuUI8 is a value duplication of eV40IkK
# id uDEtgz3 is a value duplication of uGxjAJM
# id FhHeqEK is a value duplication of hSLtFMf
# id LWDnlkK contains blocked words
# id coI5UJ8 is a value duplication of SCk4ZLX
# id bm7luuo is a value duplication of QpJQ0AO
# id Q1yEQyQ is a value duplication of emOmHkF
# id ZrwbsQ3 is a value duplication of DtGvdmE
# id f26JnGM is too short
# id dKscwQf contains blocked words
# id 8uojngH contains blocked words
# id P6bVPGZ contains blocked words
# id HszdESH is a value duplication of h4mff6f
# id IFq2RzE has a wrong format
# id PbJM5eD is a value duplication of d4YrpHD
# id wMnUfRu is a value duplication of RvT5t3h
# id mq9XmCf is a value duplication of fud9GZG
# id iQsidSj is a value duplication of WmzIZYQ
# id Y3w6414 has a wrong format
# id 2wFaBiS is too short
# id 9J7vATs is too short
# id jWoBqJc is a value duplication of HdYnQob
# id Kn2Y1v7 contains blocked words
# id oz7OB4Z is a value duplication of n5YGX6B
# id 5EsrW9o contains blocked words
# id Cf47Vg3 is a value duplication of IBdyaub
# id XwNF6mK is a value duplication of 2afgZcd
# id zUUqmoW is too short
# id roBz3ZR has a wrong format
# id S4x5kAJ contains blocked words
# id dza3xMR contains blocked words
# id OvhDgco is a value duplication of a2ujQzj
# id tVwdiJ1 is a value duplication of Zegdf65
# id yjYst6V contains blocked words
# id s0prjoF contains blocked words
# id bIV6qCz contains blocked words
# id 880PWPO contains blocked words
# id FW0SO7N is a value duplication of lxg5WbU
# id Ro242Nz is too short
# id uZAAvyn is a value duplication of 947BGNH
# id NCt3YH3 is a value duplication of zLS3oiY
# id uwDNY9T has a wrong format
# id UCNleIn contains blocked words
# id 096iDZy is too short
# id XHt4kwg is a value duplication of l2uDNVc
# id UhDVOg8 is a value duplication of J6hOJZz
# id cZRKCKv is too short
# id cPKBVkS contains blocked words
# id ztU820O is a value duplication of e1D2h1P
# id w9cRu4B contains blocked words
# id wZu1VHG is a value duplication of 4AwsYGR
# id sL9rd6b is a value duplication of g6B3AIr
# id 8yRx7DS is a value duplication of gFQBlb0
# id JDc4NwZ is a value duplication of x25sNIb
# id 8lKvF8K has a wrong format
# id Y1Ds4MR is too short
# id NHjJLUX is a value duplication of Y1IKcj7
# id MLPaNPp is a value duplication of srHsUat
# id K3LHERc contains blocked words
# id KCuu5gy is a value duplication of j0G4Mkm
# id KdT3lNr contains blocked words
# id H8Dl2Md contains blocked words
# id E849cX8 contains blocked words
# id DC8S2Y7 is a value duplication of R7QfoeI
# id 6YtFhBl is a value duplication of 3mT2l9i
# id Vbg0ogH is a value duplication of BIxxjMX
# id gk8f6EL contains blocked words
# id XG4BPPe is a value duplication of vg1xjb8
# id rYG4xCD contains blocked words
# id 8khgWja has a wrong format
# id KzpB7mY contains blocked words
# id u2GdcTA contains blocked words
# id VduoMsn is a value duplication of ZDnF4lM
# id Oo9oN7g has a wrong format
# id 5e8rauM contains blocked words
# id eqF9YnU is too short
# id GHsVJQh has a wrong format
# id 0w4MNti contains blocked words
# id lfwcnYo is a value duplication of ir8kYa3
# id RKSZ5Re is a value duplication of VQdx1Ss
# id 6g02knJ contains blocked words
# id tmyZX2p contains blocked words
# id 3WSxcMd contains blocked words
# id fDvYoAG contains blocked words
# id siZd04I contains blocked words
# id ugjhHO5 contains blocked words
# id pgAWaNy contains blocked words
# id dZLjwnZ has a wrong format
# id W9M3xyW is a value duplication of a5A4dx6
# id FYeKrS6 is too short
# id VpPcERq is a value duplication of AluRov4
# id 2I5Bw2V contains blocked words
# id B4SGdBH is a value duplication of Yr4yRnP
# id eNzCpb2 has a wrong format
# id BEVh3VE is a value duplication of DepSThA
# id 3G3DBAX is a value duplication of P5GgG0R
# id kDip0Cb contains blocked words
# id AZrfiOu is a value duplication of LcrQJrd
# id WXAFuy6 contains blocked words
# id 5miHaIb is a value duplication of AGhlfub
# id WMKldpY has a wrong format
# id TvNdJkO is a value duplication of BRXPLEf
# id 9DXSrfw has a wrong format
# id 4HtKEwF is too short
# id MTGnTDy is a value duplication of 0evj6mZ
# id DSdzy1T is a value duplication of ZwNbOKY
# id 1IYWsh1 contains blocked words
# id oulKMGx contains blocked words
# id fl9ZNLy is a value duplication of KUUh5jS
# id YCmMrSy contains blocked words
# id 8w0MhIA is a value duplication of gCUfOZS
# id mT1gQYr is a value duplication of xv8xksu
# id SoyhGNj is a value duplication of 8h7XU8m
# id TGXrCVF is a value duplication of 3iW1XC3
# id Vaftugj is too short
# id aB4YwjM contains blocked words
# id xRCTrHA is a value duplication of szORWR7
# id eBAiDoZ is a value duplication of aJLWHoW
# id 5qBYRdb contains blocked words
# id TeV6Nn8 is a value duplication of 66Ntcsu
# id Bf9o2wn is a value duplication of EHV1vzo
# id buRl7Go is too short
# id 6kukI9U is a value duplication of cPluJEh
# id O8jqumH contains blocked words
# id M7nfQfu contains blocked words
# id MG0FT1K is a value duplication of wTgc6R4
# id DcvleOC is too short
# id JQ7OGpl contains blocked words
# id ifMqVxV contains blocked words
# id nHnEtj0 contains blocked words
# id 7Wm2gbs has a wrong format
# id 8ipZQ7h is a value duplication of tvBpRYj
# id ZDBqqPp contains blocked words
# id Bt7Jpzf is too short
# id oJosj5f contains blocked words
# id GAzwHmz contains blocked words
# id QucSxw6 is a value duplication of 2HZImWg
# id dUPekF4 contains blocked words
# id N3oMEGG contains blocked words
# id 8qrEoVS has a wrong format
# id GE6XqJj contains blocked words
# id MTaL5Pk contains blocked words
# id Hifb8iN is a value duplication of ImqOFBj
# id F3kWr3u is a value duplication of u30Od99
# id 3B86QCg contains blocked words
# total: 45331, skip: 11170, new: 34161, cnt_blocked_words: 4463, cnt_parser_error: 0, cnt_wrong_format: 1115, cnt_too_short: 1728, cnt_id_duplication: 0, cnt_value_duplication: 3864, cnt_plugin: 0

# %%
import json

try:
    with open("/content/sharegpt_clean.json", 'r') as file:
        data = json.load(file)
        print("File read successfully.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# File read successfully.

# %%
import pandas as pd

# %%
df_rows = []
for item in data:
    id = item['id']
    for conversation in item['conversations']:
        df_rows.append([id, conversation['from'], conversation['value']])

# Creating a DataFrame
df = pd.DataFrame(df_rows, columns=['id', 'from', 'value'])

# Saving the DataFrame to a pickle file
df.to_pickle('/content/df_conversations.pkl')

# The DataFrame is now saved as a pickle file
df.head()
# Out:
#         id   from                                              value
# 0  QWJhYvA  human  Summarize the main ideas of Jeff Walker's Prod...
# 1  QWJhYvA    gpt  Here are the main ideas of Jeff Walker's Produ...
# 2  QWJhYvA  human  Summarize the main ideas of Brendon Burchard's...
# 3  QWJhYvA    gpt  Here are the main ideas of Brendon Burchard's ...
# 4  QWJhYvA  human  What are the mental triggers in Jeff Walker's ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448568 entries, 0 to 448567
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      448568 non-null  object
#  1   from    448568 non-null  object
#  2   value   448568 non-null  object
# dtypes: object(3)
# memory usage: 10.3+ MB
